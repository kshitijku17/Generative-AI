# %%
x=10

# %%
x
# Out:
# 10

# %%
mysub = "python"
mysub
# Out:
# 'python'

# %%
my_city1 = "shimal"
my_city1
# Out:
# 'shimal'

# %%
_mycity = "solan"
_mycity
# Out:
# 'solan'

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
x=1
type(x)
# Out:
# int

# %%
y=3.14
type(y)
# Out:
# float

# %%
z=3+4j
type(z)
# Out:
# complex

# %%
x="solan"
type(x)
# Out:
# str

# %%
a= True
type(a)
# Out:
# bool

# %%
b= False
type (b)
# Out:
# bool

# %%
e= None
type(e)
# Out:
# NoneType

# %%
#single quotes
my_sub = 'Gen AI'
type(my_sub)
# Out:
# str

# %%
#double quotes
my_clg = "shoolini university"
type(my_clg)
# Out:
# str

# %%
#triple quotes
my_sentence = '''this senetence is written in triple quotes
this is also a string'''
type(my_sentence)
# Out:
# str

# %%
my_sub = "Machine learning"
len(my_sub)
# Out:
# 16

# %%
my_sub = "Machine learning"
my_sub[0]
# Out:
# 'M'

# %%
my_sub[-16]
# Out:
# 'M'

# %%
my_sub[7]
# Out:
# ' '

# %%
my_sub[-5]
# Out:
# 'r'

# %%
my_sub[0:7:1]
# Out:
# 'Machine'

# %%
my_sub[8::]
# Out:
# 'learning'

# %%
my_sub[0:15:2]
# Out:
# 'Mcielann'

# %%
my_sub[-1::-1]
# Out:
# 'gninrael enihcaM'

# %%
my_sub = "PYTHON"
my_sub.lower()
# Out:
# 'python'

# %%
#upper()--this method convert string into uppercase
my_string = "machine learing"
my_string.upper()
# Out:
# 'MACHINE LEARING'

# %%
my_string = "machine learing"
my_string.upper()
# Out:
# 'MACHINE LEARING'

# %%
#count()-- thios method count the number of character
my_string = "machine learing"
my_string.count(' ')
# Out:
# 1

# %%
my_string = "machine learing"
my_string.count('a')
# Out:
# 2

# %%
my_list = [17, "apple", 3.14, 69]
type(my_list)
# Out:
# list

# %%
fruit_list = ["apple", "banana", "cherry"]
type(fruit_list)
# Out:
# list

# %%
my_list = [17, "apple", 3.14, 69]
len(my_list)
# Out:
# 4

# %%
print(my_list)
# Out:
# [17, 'apple', 3.14, 69]

# %%
my_list = [78, 89, 23, 75,22]
my_list[0]
# Out:
# 78

# %%
my_list = [78, 89, 23, 75,22]
my_list[-3]
# Out:
# 23

# %%
my_list =[78, 89, 23, 75,22]
print(my_list[0:])
# Out:
# [78, 89, 23, 75, 22]

# %%
my_list [: :-1]
# Out:
# [22, 75, 23, 89, 78]

# %%
list1 = [7,8,5,4,2]
min(list1)
# Out:
# 2

# %%
#max()--this fuction find maximum of the list
max(list1)
# Out:
# 8

# %%
#sum()--this fuction return addition of the item
sum(list1)
# Out:
# 26

# %%
 #sorted()-- this fuction arrange lit in inc or dec order
 my_list = [89,90,56,34,100,45]
 sorted(my_list, reverse=True)
# Out:
# [100, 90, 89, 56, 45, 34]

# %%
my_list
# Out:
# [89, 90, 56, 34, 100, 45]

# %%
#append()-- this method add the item end of the list
list1 =[89,76,56]
list1.append(100)
list1
# Out:
# [89, 76, 56, 100]

# %%
#extend()--this method used to merge list into another list
list1 = [89,76,56]
list2 = [100,200,300]
list1.extend(list2)
list1
# Out:
# [89, 76, 56, 100, 200, 300]

# %%
#sort()--this method arrange list in inc or dec order
my_list = [12,45,67,34]
my_list.sort(reverse = True)
my_list
# Out:
# [67, 45, 34, 12]

# %%
#pop()-- this method remove item from list,and take index as argument
list1 = [90,78,45,32,69]
list1.pop(-3)
# Out:
# 45

# %%
#reverse()--this method use to reverse the list
my_list = [90,78,45,100]
my_list
# Out:
# [90, 78, 45, 100]

# %%
my_dict = {"name":"john","age":25,"city":"New York"}
type(my_dict)
# Out:
# dict
